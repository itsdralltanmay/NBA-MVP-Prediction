# %%
import pandas as pd

# %%
stats = pd.read_csv("player_mvp_stats.csv")

# %%
stats
# Out:
#        Unnamed: 0                 Player Pos  Age   Tm   G  GS    MP   FG  \
# 0               0             A.C. Green  PF   27  LAL  82  21  26.4  3.1
# 1               1            Byron Scott  SG   29  LAL  82  82  32.1  6.1
# 2               2         Elden Campbell  PF   22  LAL  52   0   7.3  1.1
# 3               3          Irving Thomas  PF   25  LAL  26   0   4.2  0.7
# 4               4           James Worthy  SF   29  LAL  78  74  38.6  9.2
# 5               5             Larry Drew  PG   32  LAL  48   2  10.3  1.1
# 6               6          Magic Johnson  PG   31  LAL  79  79  37.1  5.9
# 7               7        Mychal Thompson   C   36  LAL  72   4  15.0  1.6
# 8               8            Sam Perkins  PF   29  LAL  73  66  34.3  5.0
# 9               9           Terry Teagle  SG   30  LAL  82   0  18.3  4.1
# 10             10             Tony Smith  SG   22  LAL  64   1  10.9  1.5
# 11             11            Vlade Divac   C   22  LAL  82  81  28.2  4.4
# ...

# %%
del stats["Unnamed: 0"]

# %%
pd.isnull(stats).sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          50
# 3P            0
# 3PA           0
# 3P%        2042
# 2P            0
# 2PA           0
# 2P%          84
# eFG%         50
# FT            0
# FTA           0
# FT%         462
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
stats = stats.fillna(0)

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = ['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year', 'W', 'L', 'W/L%', 'GB', 'PS/G',
       'PA/G', 'SRS']

# %%
train = stats[stats["Year"] < 2021]

# %%
test = stats[stats["Year"] == 2021]

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha = .1)

# %%
reg.fit(train[predictors], train["Share"])
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
predictions = reg.predict(test[predictors])

# %%
predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)

# %%
predictions
# Out:
#        predictions
# 630       0.013567
# 631      -0.013756
# 632       0.002414
# 633      -0.004421
# 634       0.010734
# 635      -0.004239
# 636       0.013357
# 637       0.042044
# 638      -0.001333
# 639       0.054226
# 640       0.002354
# 641       0.154307
# 642      -0.008234
# 643       0.015891
# 644      -0.009516
# 645      -0.001751
# 646      -0.007538
# 647      -0.007768
# 840      -0.015638
# 841      -0.013118
# 842      -0.004117
# 843       0.051787
# 844      -0.010328
# 845       0.089141
# 846       0.010593
# 847      -0.012419
# 848       0.000455
# 849      -0.018945
# 850      -0.003614
# 851       0.005688
# ...            ...
# 13470    -0.004839
# 13471     0.016378
# 13472    -0.009977
# 13473    -0.015098
# 13474     0.047174
# 13475     0.007918
# 13476    -0.051316
# 13477     0.029111
# 13478    -0.008959
# 13479    -0.000313
# 13480    -0.003234
# 13481    -0.024617
# 13482    -0.023287
# 13483    -0.006943
# 13886     0.081817
# ...

# %%
combination = pd.concat([test[["Player","Share"]], predictions], axis=1)

# %%
combination
# Out:
#                        Player  Share  predictions
# 630              Aaron Gordon  0.000     0.013567
# 631             Austin Rivers  0.000    -0.013756
# 632                   Bol Bol  0.000     0.002414
# 633          Facundo Campazzo  0.000    -0.004421
# 634          Greg Whittington  0.000     0.010734
# 635            JaMychal Green  0.000    -0.004239
# 636              JaVale McGee  0.000     0.013357
# 637              Jamal Murray  0.000     0.042044
# 638             Markus Howard  0.000    -0.001333
# 639        Michael Porter Jr.  0.000     0.054226
# 640              Monte Morris  0.000     0.002354
# 641              Nikola Jokić  0.961     0.154307
# 642                 PJ Dozier  0.000    -0.008234
# 643              Paul Millsap  0.000     0.015891
# 644        Shaquille Harrison  0.000    -0.009516
# 645             Vlatko Čančar  0.000    -0.001751
# 646               Will Barton  0.000    -0.007538
# 647                Zeke Nnaji  0.000    -0.007768
# ...

# %%
combination.sort_values("Share", ascending=False).head(10)
# Out:
#                       Player  Share  predictions
# 641             Nikola Jokić  0.961     0.154307
# 8624             Joel Embiid  0.580     0.162713
# 3651           Stephen Curry  0.449     0.142386
# 9907   Giannis Antetokounmpo  0.345     0.207436
# 1389              Chris Paul  0.138     0.072294
# 10997            Luka Dončić  0.042     0.151430
# 7464          Damian Lillard  0.038     0.116303
# 3536           Julius Randle  0.020     0.088878
# 3531            Derrick Rose  0.010     0.033000
# 11358            Rudy Gobert  0.008     0.095349

# %%
#Error Matrix
from sklearn.metrics import mean_squared_error
mean_squared_error(combination["Share"], combination["predictions"])
# Out:
# 0.0026668954567104063

# %%
combination["Share"].value_counts() #Gives the count of individual values
# Out:
# 0.000    525
# 0.001      3
# 0.961      1
# 0.138      1
# 0.042      1
# 0.038      1
# 0.020      1
# 0.003      1
# 0.008      1
# 0.005      1
# 0.580      1
# 0.449      1
# 0.010      1
# 0.345      1
# Name: Share, dtype: int64

# %%
combination = combination.sort_values("Share", ascending=False)
combination["Rk"] = list(range(1, combination.shape[0] + 1))

# %%
combination.head(10)
# Out:
#                       Player  Share  predictions  Rk
# 641             Nikola Jokić  0.961     0.154307   1
# 8624             Joel Embiid  0.580     0.162713   2
# 3651           Stephen Curry  0.449     0.142386   3
# 9907   Giannis Antetokounmpo  0.345     0.207436   4
# 1389              Chris Paul  0.138     0.072294   5
# 10997            Luka Dončić  0.042     0.151430   6
# 7464          Damian Lillard  0.038     0.116303   7
# 3536           Julius Randle  0.020     0.088878   8
# 3531            Derrick Rose  0.010     0.033000   9
# 11358            Rudy Gobert  0.008     0.095349  10

# %%
combination = combination.sort_values("predictions", ascending=False)
combination["Predicted_Rk"] = list(range(1, combination.shape[0] + 1))

# %%
combination.head(10)
# Out:
#                       Player  Share  predictions   Rk  Predicted_Rk
# 9907   Giannis Antetokounmpo  0.345     0.207436    4             1
# 8624             Joel Embiid  0.580     0.162713    2             2
# 641             Nikola Jokić  0.961     0.154307    1             3
# 10997            Luka Dončić  0.042     0.151430    6             4
# 3736            LeBron James  0.001     0.147511   15             5
# 3651           Stephen Curry  0.449     0.142386    3             6
# 4177            Kevin Durant  0.000     0.141350  531             7
# 4174            James Harden  0.001     0.140598   13             8
# 11784        Zion Williamson  0.000     0.127926  251             9
# 3876       Russell Westbrook  0.005     0.120228   11            10

# %%
combination.sort_values("Share", ascending=False).head(10)
# Out:
#                       Player  Share  predictions  Rk  Predicted_Rk
# 641             Nikola Jokić  0.961     0.154307   1             3
# 8624             Joel Embiid  0.580     0.162713   2             2
# 3651           Stephen Curry  0.449     0.142386   3             6
# 9907   Giannis Antetokounmpo  0.345     0.207436   4             1
# 1389              Chris Paul  0.138     0.072294   5            33
# 10997            Luka Dončić  0.042     0.151430   6             4
# 7464          Damian Lillard  0.038     0.116303   7            12
# 3536           Julius Randle  0.020     0.088878   8            24
# 3531            Derrick Rose  0.010     0.033000   9            76
# 11358            Rudy Gobert  0.008     0.095349  10            19

# %%
def find_ap(combination):
    actual = combination.sort_values("Share", ascending=False).head(5)
    predicted = combination.sort_values("predictions", ascending=False)
    ps = []
    found = 0
    seen = 1
    for index, row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found/seen)
        seen += 1
    return sum(ps) / len(ps) #Aggregate ps to get our error metric

# %%
#Prediction for 2021
find_ap(combination) #This must be as high as possible (Max 1)
# Out:
# 0.7636363636363636

# %%
years = list(range(1991,2022))

# %%
#Mean average prediction for all years
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats["Year"]<year]
    test = stats[stats["Year"]==year]
    reg.fit(train[predictors], train["Share"])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
    combination = pd.concat([test[["Player","Share"]], predictions], axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

# %%
sum(aps)/len(aps) #Algo works littlw=e worst for entire data, but still pretty acurate
# Out:
# 0.7112884360789578

# %%
def add_ranks(combination):
    combination = combination.sort_values("Share", ascending=False)
    combination["Rk"] = list(range(1, combination.shape[0] + 1))
    combination = combination.sort_values("predictions", ascending=False)
    combination["Predicted_Rk"] = list(range(1, combination.shape[0] + 1))
    combination["Diff"] = combination["Rk"] - combination["Predicted_Rk"]
    return combination

# %%
ranking = add_ranks(all_predictions[1])
ranking[ranking["Rk"] < 6].sort_values("Diff", ascending=False)
# Out:
#                Player  Share  predictions  Rk  Predicted_Rk  Diff
# 1600      Karl Malone  0.857     0.192318   1             2    -1
# 10524  Michael Jordan  0.832     0.167629   2             3    -1
# 908        Grant Hill  0.327     0.128646   3             6    -3
# 4682     Tim Hardaway  0.207     0.059984   4            20   -16
# 8248        Glen Rice  0.117     0.033110   5            53   -48

# %%
#Single function for all the things we did above seperately
def backtest(stats, model, year, predictors):
    aps = []
    all_predictions = []
    for year in years[5:]:
        train = stats[stats["Year"]<year]
        test = stats[stats["Year"]==year]
        model.fit(train[predictors], train["Share"])
        predictions = reg.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
        combination = pd.concat([test[["Player","Share"]], predictions], axis=1)
        combination = add_ranks(combination)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps)/len(aps), aps, pd.concat(all_predictions)

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7112884360789578

# %%
all_predictions[all_predictions["Rk"] <= 5].sort_values("Diff").head(10)
# Out:
#                  Player  Share  predictions  Rk  Predicted_Rk  Diff
# 1224         Jason Kidd  0.712     0.028209   2            52   -50
# 8248          Glen Rice  0.117     0.033110   5            53   -48
# 5175         Steve Nash  0.839     0.034100   1            45   -44
# 8516    Peja Stojaković  0.228     0.036269   4            38   -34
# 5193         Steve Nash  0.739     0.054128   1            34   -33
# 12726       Joakim Noah  0.258     0.046968   4            37   -33
# 3657   Chauncey Billups  0.344     0.052698   5            35   -30
# 1389         Chris Paul  0.138     0.072294   5            33   -28
# 5208         Steve Nash  0.785     0.074421   2            21   -19
# 4682       Tim Hardaway  0.207     0.059984   4            20   -16

# %%
#To find which predictors are most influential in predicting
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1).sort_values(0, ascending=False)
# Out:
#            0     1
# 13  0.070002  eFG%
# 18  0.035041   DRB
# 29  0.027126  W/L%
# 17  0.021610   ORB
# 10  0.016945    2P
# 21  0.011635   STL
# 15  0.011351   FTA
# 22  0.011234   BLK
# 20  0.007456   AST
# 25  0.005893   PTS
# 4   0.005694    FG
# 5   0.005516   FGA
# 7   0.004569    3P
# 12  0.004083   2P%
# 0   0.000321   Age
# 30  0.000270    GB
# 27  0.000098     W
# 1   0.000092     G
# 2  -0.000006    GS
# 26 -0.000184  Year
# 32 -0.000219  PA/G
# 28 -0.000295     L
# 33 -0.000521   SRS
# 31 -0.000556  PS/G
# 24 -0.002634    PF
# 3  -0.004150    MP
# 16 -0.004575   FT%
# 14 -0.006585    FT
# 23 -0.009696   TOV
# 9  -0.009822   3P%
# 8  -0.010394   3PA
# 11 -0.017318   2PA
# 19 -0.027506   TRB
# 6  -0.135025   FG%

# %%
#Adding more predictors
stat_ratios = stats[["PTS", "AST", "STL", "BLK", "3P", "Year"]].groupby("Year").apply(lambda x: x/x.mean())

# %%
stat_ratios
# Out:
#             PTS       AST       STL       BLK        3P  Year
# 0      1.013334  0.420714  0.961127  0.673469  0.508587   1.0
# 1      1.614653  1.028412  1.647646  0.673469  4.577279   1.0
# 2      0.311795  0.093492  0.274608  1.571429  0.000000   1.0
# 3      0.200440  0.186984  0.274608  0.000000  0.000000   1.0
# 4      2.383005  1.636110  1.784950  0.897959  1.525760   1.0
# 5      0.322931  1.168650  0.411912  0.000000  1.525760   1.0
# 6      2.160294  5.843249  1.784950  0.448980  5.085865   1.0
# 7      0.445421  0.140238  0.411912  0.673469  0.000000   1.0
# 8      1.503297  0.701190  1.235735  2.469388  1.017173   1.0
# 9      1.102418  0.467460  0.549215  0.224490  0.000000   1.0
# 10     0.412015  0.981666  0.549215  0.448980  0.000000   1.0
# 11     1.247180  0.514206  1.784950  3.367347  0.508587   1.0
# 12     1.534567  0.678383  1.500353  0.853510  0.456805   1.0
# 13     1.681253  1.356766  1.773145  0.640133  3.197633   1.0
# ...

# %%
stats[["PTS_T", "AST_R", "STL_R", "BLK_R", "3P_R"]] = stat_ratios[["PTS", "AST", "STL", "BLK", "3P"]]

# %%
stats.head(10)
# Out:
#             Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...   W/L%  \
# 0       A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  0.707
# 1      Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...  0.707
# 2   Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...  0.707
# 3    Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...  0.707
# 4     James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...  0.707
# 5       Larry Drew  PG   32  LAL  48   2  10.3  1.1   2.6  0.432  ...  0.707
# 6    Magic Johnson  PG   31  LAL  79  79  37.1  5.9  12.4  0.477  ...  0.707
# 7  Mychal Thompson   C   36  LAL  72   4  15.0  1.6   3.2  0.496  ...  0.707
# 8      Sam Perkins  PF   29  LAL  73  66  34.3  5.0  10.2  0.495  ...  0.707
# 9     Terry Teagle  SG   30  LAL  82   0  18.3  4.1   9.2  0.443  ...  0.707
#
#     GB   PS/G  PA/G   SRS     PTS_T     AST_R     STL_R     BLK_R      3P_R
# ...

# %%
predictors += ["PTS_T", "AST_R", "STL_R", "BLK_R", "3P_R"]

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
#Prediction improved
mean_ap
# Out:
# 0.7208380973034985

# %%
stats["NPos"] = stats["Pos"].astype("category").cat.codes

# %%
stats["NTm"] = stats["Tm"].astype("category").cat.codes

# %%
stats["NTm"].value_counts() #Its difficult for linear regression to predict from categorical relations
# Out:
# 7     499
# 27    495
# 8     493
# 14    493
# 11    492
# 17    491
# 12    490
# 0     485
# 9     480
# 31    479
# 1     479
# 26    476
# 15    475
# 18    475
# 13    474
# 5     473
# 24    468
# 19    466
# 30    465
# 34    464
# 28    463
# 29    463
# 10    461
# 33    421
# 36    387
# 20    343
# 16    331
# 32    263
# 25    214
# 4     177
# 2     165
# 3     157
# 23    145
# 21    143
# 37    114
# 6     113
# 35     88
# 22     32
# Name: NTm, dtype: int64

# %%
#We will use KNN for that
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 50, random_state = 1, min_samples_split = 5)
mean_ap, aps, all_predictions = backtest(stats, rf, years[28:], predictors)

# %%
mean_ap #KNN proved to be more accurate
# Out:
# 0.7456311092998757

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[28:], predictors)

# %%
mean_ap
# Out:
# 0.7208380973034985
